# %% [markdown]
# # 0. Setup Paths

# %%
import os

# %%
#from tensorflow model zoo
CUSTOM_MODEL_NAME = 'my_ssd_mobnet' 
#downloaded name
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
#URL from github
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %% [markdown]
# # 1. Download TF Models Pretrained Models from Tensorflow Model Zoo and Install TFOD

# %%
# https://www.tensorflow.org/install/source_windows

# %%
if os.name=='nt':
    # !pip install wget
    #used to pull a model from model zoo
    import wget
# Out:
# Requirement already satisfied: wget in e:\anaconda\envs\tfod2\lib\site-packages (3.2)

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}
# Out:
# Cloning into 'Tensorflow\models'...
# Updating files:  59% (1709/2861)
# Updating files:  60% (1717/2861)
# Updating files:  61% (1746/2861)
# Updating files:  62% (1774/2861)
# Updating files:  63% (1803/2861)
# Updating files:  64% (1832/2861)
# Updating files:  65% (1860/2861)
# Updating files:  66% (1889/2861)
# Updating files:  67% (1917/2861)
# Updating files:  68% (1946/2861)
# Updating files:  69% (1975/2861)
# Updating files:  70% (2003/2861)
# Updating files:  71% (2032/2861)
# Updating files:  72% (2060/2861)
# Updating files:  73% (2089/2861)
# Updating files:  74% (2118/2861)
# Updating files:  75% (2146/2861)
# Updating files:  76% (2175/2861)
# Updating files:  77% (2203/2861)
# Updating files:  78% (2232/2861)
# Updating files:  79% (2261/2861)
# Updating files:  80% (2289/2861)
# Updating files:  81% (2318/2861)
# Updating files:  82% (2347/2861)
# Updating files:  83% (2375/2861)
# Updating files:  84% (2404/2861)
# Updating files:  85% (2432/2861)
# Updating files:  86% (2461/2861)
# Updating files:  87% (2490/2861)
# Updating files:  88% (2518/2861)
# Updating files:  89% (2547/2861)
# Updating files:  90% (2575/2861)
# Updating files:  91% (2604/2861)
# Updating files:  92% (2633/2861)
# Updating files:  93% (2661/2861)
# Updating files:  94% (2690/2861)
# Updating files:  95% (2718/2861)
# Updating files:  96% (2747/2861)
# Updating files:  97% (2776/2861)
# Updating files:  98% (2804/2861)
# Updating files:  99% (2833/2861)
# Updating files: 100% (2861/2861)
# Updating files: 100% (2861/2861), done.

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .
# Out:
#  68% [..................................................                        ]  999424 / 1468733
# 100% [..........................................................................] 1468733 / 1468733        1 file(s) moved.
#         1 file(s) copied.
# E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\easy_install.py:156: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# zip_safe flag not set; analyzing archive contents...
# object_detection.core.__pycache__.densepose_ops.cpython-39: module references __file__
# object_detection.core.__pycache__.preprocessor.cpython-39: module MAY be using inspect.stack
# object_detection.utils.__pycache__.autoaugment_utils.cpython-39: module MAY be using inspect.stack
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning:  is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-0.6.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.0.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.1.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.1.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.2.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.3.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.4.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.5.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.6.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.7.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.8.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.9.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.10.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.11.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.12.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.13.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.14.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.15.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.16.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.17.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.18.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.19.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.20.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.21.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.22.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.23.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.24.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.25.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.26.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.27.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.28.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.29.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.29.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.30.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.30.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.31.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.31.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.32.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.32.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.33.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.33.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.33.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.34.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.34.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.34.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.35.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.35.0rc3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.35.0rc5 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.35.0rc6 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.35.0rc8 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: beam-2.35.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\chira\AppData\Local\Temp\easy_install-28u74zh2\apache-beam-2.35.0\setup.py:98: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if StrictVersion(_PIP_VERSION) < StrictVersion(REQUIRED_PIP_VERSION):
# C:\Users\chira\AppData\Local\Temp\easy_install-28u74zh2\apache-beam-2.35.0\setup.py:109: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if StrictVersion(_CYTHON_VERSION) < StrictVersion(REQUIRED_CYTHON_VERSION):
# C:\Users\chira\AppData\Local\Temp\easy_install-28u74zh2\apache-beam-2.35.0\setup.py:256: UserWarning: This version of Apache Beam has not been sufficiently tested on Python 3.9. You may encounter bugs or missing features.
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\chira\AppData\Local\Temp\easy_install-28u74zh2\apache-beam-2.35.0\apache_beam\coders\coder_impl.pxd
#   tree = Parsing.p_module(s, pxd, full_module_name)
# E:\Anaconda\envs\tfod2\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\chira\AppData\Local\Temp\easy_install-28u74zh2\apache-beam-2.35.0\apache_beam\metrics\cells.pxd
#   tree = Parsing.p_module(s, pxd, full_module_name)
# E:\Anaconda\envs\tfod2\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\chira\AppData\Local\Temp\easy_install-28u74zh2\apache-beam-2.35.0\apache_beam\metrics\execution.pxd
#   tree = Parsing.p_module(s, pxd, full_module_name)
# E:\Anaconda\envs\tfod2\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\chira\AppData\Local\Temp\easy_install-28u74zh2\apache-beam-2.35.0\apache_beam\runners\common.pxd
#   tree = Parsing.p_module(s, pxd, full_module_name)
# E:\Anaconda\envs\tfod2\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\chira\AppData\Local\Temp\easy_install-28u74zh2\apache-beam-2.35.0\apache_beam\runners\worker\opcounters.pxd
#   tree = Parsing.p_module(s, pxd, full_module_name)
# E:\Anaconda\envs\tfod2\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\chira\AppData\Local\Temp\easy_install-28u74zh2\apache-beam-2.35.0\apache_beam\runners\worker\operations.pxd
#   tree = Parsing.p_module(s, pxd, full_module_name)
# E:\Anaconda\envs\tfod2\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\chira\AppData\Local\Temp\easy_install-28u74zh2\apache-beam-2.35.0\apache_beam\transforms\cy_combiners.pxd
#   tree = Parsing.p_module(s, pxd, full_module_name)
# E:\Anaconda\envs\tfod2\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\chira\AppData\Local\Temp\easy_install-28u74zh2\apache-beam-2.35.0\apache_beam\transforms\stats.pxd
#   tree = Parsing.p_module(s, pxd, full_module_name)
# E:\Anaconda\envs\tfod2\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\chira\AppData\Local\Temp\easy_install-28u74zh2\apache-beam-2.35.0\apache_beam\utils\counters.pxd
#   tree = Parsing.p_module(s, pxd, full_module_name)
# E:\Anaconda\envs\tfod2\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\chira\AppData\Local\Temp\easy_install-28u74zh2\apache-beam-2.35.0\apache_beam\utils\windowed_value.pxd
#   tree = Parsing.p_module(s, pxd, full_module_name)
# E:\Anaconda\envs\tfod2\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\chira\AppData\Local\Temp\easy_install-28u74zh2\apache-beam-2.35.0\apache_beam\coders\stream.pxd
#   tree = Parsing.p_module(s, pxd, full_module_name)
# E:\Anaconda\envs\tfod2\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\chira\AppData\Local\Temp\easy_install-28u74zh2\apache-beam-2.35.0\apache_beam\runners\worker\statesampler_fast.pxd
#   tree = Parsing.p_module(s, pxd, full_module_name)
# E:\Anaconda\envs\tfod2\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\chira\AppData\Local\Temp\easy_install-28u74zh2\apache-beam-2.35.0\apache_beam\transforms\cy_dataflow_distribution_counter.pxd
#   tree = Parsing.p_module(s, pxd, full_module_name)
# C:\Users\chira\AppData\Local\Temp\easy_install-28u74zh2\apache-beam-2.35.0\gen_protos.py:240: UserWarning: Installing grpcio-tools is recommended for development.
#   warnings.warn('Installing grpcio-tools is recommended for development.')
# --- Logging error ---
# Traceback (most recent call last):
#   File "E:\Anaconda\envs\tfod2\lib\logging\__init__.py", line 1086, in emit
#     stream.write(msg + self.terminator)
# ValueError: underlying buffer has been detached
# Call stack:
#   File "D:\Research\FutDetectV2\Tensorflow\models\research\setup.py", line 26, in <module>
#     setup(
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\__init__.py", line 155, in setup
#     return distutils.core.setup(**attrs)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\_distutils\core.py", line 148, in setup
#     return run_commands(dist)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\_distutils\core.py", line 163, in run_commands
#     dist.run_commands()
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\_distutils\dist.py", line 967, in run_commands
#     self.run_command(cmd)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\_distutils\dist.py", line 986, in run_command
#     cmd_obj.run()
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\install.py", line 74, in run
#     self.do_egg_install()
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\install.py", line 124, in do_egg_install
#     cmd.run(show_deprecation=False)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\easy_install.py", line 421, in run
#     self.easy_install(spec, not self.no_deps)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\easy_install.py", line 663, in easy_install
#     return self.install_item(None, spec, tmpdir, deps, True)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\easy_install.py", line 710, in install_item
#     self.process_distribution(spec, dist, deps)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\easy_install.py", line 755, in process_distribution
#     distros = WorkingSet([]).resolve(
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py", line 771, in resolve
#     dist = best[req.key] = env.best_match(
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py", line 1056, in best_match
#     return self.obtain(req, installer)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py", line 1068, in obtain
#     return installer(requirement)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\easy_install.py", line 682, in easy_install
#     return self.install_item(spec, dist.location, tmpdir, deps)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\easy_install.py", line 708, in install_item
#     dists = self.install_eggs(spec, download, tmpdir)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\easy_install.py", line 901, in install_eggs
#     return self.build_and_install(setup_script, setup_base)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\easy_install.py", line 1173, in build_and_install
#     self.run_setup(setup_script, setup_base, args)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\easy_install.py", line 1157, in run_setup
#     run_setup(setup_script, args)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\sandbox.py", line 259, in run_setup
#     _execfile(setup_script, ns)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\sandbox.py", line 46, in _execfile
#     exec(code, globals, locals)
#   File "C:\Users\chira\AppData\Local\Temp\easy_install-28u74zh2\apache-beam-2.35.0\setup.py", line 263, in <module>
#     setuptools.setup(
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\__init__.py", line 155, in setup
#     return distutils.core.setup(**attrs)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\_distutils\core.py", line 148, in setup
#     return run_commands(dist)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\_distutils\core.py", line 163, in run_commands
#     dist.run_commands()
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\_distutils\dist.py", line 967, in run_commands
#     self.run_command(cmd)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\_distutils\dist.py", line 986, in run_command
#     cmd_obj.run()
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\bdist_egg.py", line 155, in run
#     self.run_command("egg_info")
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\_distutils\cmd.py", line 313, in run_command
#     self.distribution.run_command(command)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\_distutils\dist.py", line 986, in run_command
#     cmd_obj.run()
#   File "C:\Users\chira\AppData\Local\Temp\easy_install-28u74zh2\apache-beam-2.35.0\setup.py", line 244, in run
#     gen_protos.generate_proto_files()
#   File "C:\Users\chira\AppData\Local\Temp\easy_install-28u74zh2\apache-beam-2.35.0\gen_protos.py", line 258, in generate_proto_files
#     log.info('No proto files; using existing generated files.')
# Message: 'No proto files; using existing generated files.'
# Arguments: ()
# warning: no files found matching 'README.md'
# warning: no files found matching 'NOTICE'
# warning: no files found matching 'LICENSE'
# warning: no files found matching 'LICENSE.python'
# E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# --- Logging error ---
# Traceback (most recent call last):
#   File "E:\Anaconda\envs\tfod2\lib\logging\__init__.py", line 1086, in emit
#     stream.write(msg + self.terminator)
# ValueError: underlying buffer has been detached
# Call stack:
#   File "D:\Research\FutDetectV2\Tensorflow\models\research\setup.py", line 26, in <module>
#     setup(
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\__init__.py", line 155, in setup
#     return distutils.core.setup(**attrs)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\_distutils\core.py", line 148, in setup
#     return run_commands(dist)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\_distutils\core.py", line 163, in run_commands
#     dist.run_commands()
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\_distutils\dist.py", line 967, in run_commands
#     self.run_command(cmd)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\_distutils\dist.py", line 986, in run_command
#     cmd_obj.run()
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\install.py", line 74, in run
#     self.do_egg_install()
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\install.py", line 124, in do_egg_install
#     cmd.run(show_deprecation=False)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\easy_install.py", line 421, in run
#     self.easy_install(spec, not self.no_deps)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\easy_install.py", line 663, in easy_install
#     return self.install_item(None, spec, tmpdir, deps, True)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\easy_install.py", line 710, in install_item
#     self.process_distribution(spec, dist, deps)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\easy_install.py", line 755, in process_distribution
#     distros = WorkingSet([]).resolve(
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py", line 771, in resolve
#     dist = best[req.key] = env.best_match(
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py", line 1056, in best_match
#     return self.obtain(req, installer)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py", line 1068, in obtain
#     return installer(requirement)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\easy_install.py", line 682, in easy_install
#     return self.install_item(spec, dist.location, tmpdir, deps)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\easy_install.py", line 708, in install_item
#     dists = self.install_eggs(spec, download, tmpdir)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\easy_install.py", line 901, in install_eggs
#     return self.build_and_install(setup_script, setup_base)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\easy_install.py", line 1173, in build_and_install
#     self.run_setup(setup_script, setup_base, args)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\easy_install.py", line 1157, in run_setup
#     run_setup(setup_script, args)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\sandbox.py", line 259, in run_setup
#     _execfile(setup_script, ns)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\sandbox.py", line 46, in _execfile
#     exec(code, globals, locals)
#   File "C:\Users\chira\AppData\Local\Temp\easy_install-28u74zh2\apache-beam-2.35.0\setup.py", line 263, in <module>
#     setuptools.setup(
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\__init__.py", line 155, in setup
#     return distutils.core.setup(**attrs)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\_distutils\core.py", line 148, in setup
#     return run_commands(dist)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\_distutils\core.py", line 163, in run_commands
#     dist.run_commands()
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\_distutils\dist.py", line 967, in run_commands
#     self.run_command(cmd)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\_distutils\dist.py", line 986, in run_command
#     cmd_obj.run()
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\bdist_egg.py", line 164, in run
#     cmd = self.call_command('install_lib', warn_dir=0)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\bdist_egg.py", line 150, in call_command
#     self.run_command(cmdname)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\_distutils\cmd.py", line 313, in run_command
#     self.distribution.run_command(command)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\_distutils\dist.py", line 986, in run_command
#     cmd_obj.run()
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\install_lib.py", line 11, in run
#     self.build()
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\_distutils\command\install_lib.py", line 105, in build
#     self.run_command('build_py')
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\_distutils\cmd.py", line 313, in run_command
#     self.distribution.run_command(command)
#   File "E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\_distutils\dist.py", line 986, in run_command
#     cmd_obj.run()
#   File "C:\Users\chira\AppData\Local\Temp\easy_install-28u74zh2\apache-beam-2.35.0\setup.py", line 244, in run
#     gen_protos.generate_proto_files()
#   File "C:\Users\chira\AppData\Local\Temp\easy_install-28u74zh2\apache-beam-2.35.0\gen_protos.py", line 258, in generate_proto_files
#     log.info('No proto files; using existing generated files.')
# Message: 'No proto files; using existing generated files.'
# Arguments: ()
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python3-1.7.6 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning:  is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python3-1.7.7 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python3-1.8.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python3-1.8.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python3-1.8.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python3-1.9.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python3-1.9.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python3-1.9.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python3-1.9.2.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python3-1.10.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python3-1.10.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python3-1.10.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\installer.py:27: SetuptoolsDeprecationWarning: setuptools.installer is deprecated. Requirements should be satisfied by a PEP 517 installer.
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: datasets-1.0.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning:  is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: datasets-1.0.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: datasets-1.1.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: datasets-1.2.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: datasets-1.3.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: datasets-1.3.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: datasets-1.3.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: datasets-2.0.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: datasets-2.1.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: datasets-3.0.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: datasets-3.1.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: datasets-3.2.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: datasets-3.2.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: datasets-4.0.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: datasets-4.0.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: datasets-4.1.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: datasets-4.2.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: datasets-4.3.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: datasets-4.4.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\installer.py:27: SetuptoolsDeprecationWarning: setuptools.installer is deprecated. Requirements should be satisfied by a PEP 517 installer.
#   warnings.warn(
# listing git files failed - pretending there aren't any
# E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# zip_safe flag not set; analyzing archive contents...
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning:  is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: cpuinfo-0.1.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: cpuinfo-0.1.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: cpuinfo-0.1.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: cpuinfo-0.1.4 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: cpuinfo-0.1.5 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: cpuinfo-0.1.6 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: cpuinfo-0.1.8 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: cpuinfo-0.2.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: cpuinfo-0.2.3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: cpuinfo-0.2.4 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: cpuinfo-0.2.5 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: cpuinfo-0.2.6 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: cpuinfo-0.2.7 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: cpuinfo-3.0.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: cpuinfo-3.1.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: cpuinfo-3.2.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: cpuinfo-3.3.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: cpuinfo-4.0.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: cpuinfo-5.0.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: cpuinfo-6.0.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: cpuinfo-7.0.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: cpuinfo-8.0.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# zip_safe flag not set; analyzing archive contents...
# cpuinfo.__pycache__.cpuinfo.cpython-39: module references __file__
# cpuinfo.__pycache__.cpuinfo.cpython-39: module MAY be using inspect.stack
# cpuinfo.__pycache__.cpuinfo.cpython-39: module MAY be using inspect.trace
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning:  is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python-headless-3.4.10.37 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: headless-3.4.10.37 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python-headless-3.4.11.39 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: headless-3.4.11.39 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python-headless-3.4.11.41 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: headless-3.4.11.41 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python-headless-3.4.11.43 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: headless-3.4.11.43 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python-headless-3.4.11.45 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: headless-3.4.11.45 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python-headless-3.4.13.47 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: headless-3.4.13.47 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python-headless-3.4.15.55 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: headless-3.4.15.55 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python-headless-3.4.16.59 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: headless-3.4.16.59 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python-headless-3.4.17.61 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: headless-3.4.17.61 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python-headless-4.3.0.38 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: headless-4.3.0.38 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python-headless-4.4.0.40 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: headless-4.4.0.40 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python-headless-4.4.0.42 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: headless-4.4.0.42 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python-headless-4.4.0.44 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: headless-4.4.0.44 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python-headless-4.4.0.46 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: headless-4.4.0.46 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python-headless-4.5.1.48 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: headless-4.5.1.48 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: python-headless-4.5.3.56 is an invalid version and will not be supported in a future release
#   warnings.warn(
# E:\Anaconda\envs\tfod2\lib\site-packages\pkg_resources\__init__.py:116: PkgResourcesDeprecationWarning: headless-4.5.3.56 is an invalid version and will not be supported in a future release
#   warnings.warn(
# ...
# byte-compiling e:\anaconda\envs\tfod2\lib\site-packages\apache_beam-2.35.0-py3.9-win-amd64.egg\apache_beam\utils\shared_test.py to shared_test.cpython-39.pyc
# byte-compiling e:\anaconda\envs\tfod2\lib\site-packages\apache_beam-2.35.0-py3.9-win-amd64.egg\apache_beam\utils\subprocess_server.py to subprocess_server.cpython-39.pyc
# byte-compiling e:\anaconda\envs\tfod2\lib\site-packages\apache_beam-2.35.0-py3.9-win-amd64.egg\apache_beam\utils\subprocess_server_test.py to subprocess_server_test.cpython-39.pyc
# byte-compiling e:\anaconda\envs\tfod2\lib\site-packages\apache_beam-2.35.0-py3.9-win-amd64.egg\apache_beam\utils\thread_pool_executor.py to thread_pool_executor.cpython-39.pyc
# byte-compiling e:\anaconda\envs\tfod2\lib\site-packages\apache_beam-2.35.0-py3.9-win-amd64.egg\apache_beam\utils\thread_pool_executor_test.py to thread_pool_executor_test.cpython-39.pyc
# byte-compiling e:\anaconda\envs\tfod2\lib\site-packages\apache_beam-2.35.0-py3.9-win-amd64.egg\apache_beam\utils\timestamp.py to timestamp.cpython-39.pyc
# byte-compiling e:\anaconda\envs\tfod2\lib\site-packages\apache_beam-2.35.0-py3.9-win-amd64.egg\apache_beam\utils\timestamp_test.py to timestamp_test.cpython-39.pyc
# byte-compiling e:\anaconda\envs\tfod2\lib\site-packages\apache_beam-2.35.0-py3.9-win-amd64.egg\apache_beam\utils\urns.py to urns.cpython-39.pyc
# byte-compiling e:\anaconda\envs\tfod2\lib\site-packages\apache_beam-2.35.0-py3.9-win-amd64.egg\apache_beam\utils\windowed_value.py to windowed_value.cpython-39.pyc
# byte-compiling e:\anaconda\envs\tfod2\lib\site-packages\apache_beam-2.35.0-py3.9-win-amd64.egg\apache_beam\utils\windowed_value_test.py to windowed_value_test.cpython-39.pyc
# Adding apache-beam 2.35.0 to easy-install.pth file
#
# Installed e:\anaconda\envs\tfod2\lib\site-packages\apache_beam-2.35.0-py3.9-win-amd64.egg
# Searching for avro-python3
# Reading https://pypi.org/simple/avro-python3/
# Downloading https://files.pythonhosted.org/packages/cc/97/7a6970380ca8db9139a3cc0b0e3e0dd3e4bc584fb3644e1d06e71e1a55f0/avro-python3-1.10.2.tar.gz#sha256=3b63f24e6b04368c3e4a6f923f484be0230d821aad65ac36108edbff29e9aaab
# Best match: avro-python3 1.10.2
# Processing avro-python3-1.10.2.tar.gz
# Writing C:\Users\chira\AppData\Local\Temp\easy_install-tyhkwf6j\avro-python3-1.10.2\setup.cfg
# Running avro-python3-1.10.2\setup.py -q bdist_egg --dist-dir C:\Users\chira\AppData\Local\Temp\easy_install-tyhkwf6j\avro-python3-1.10.2\egg-dist-tmp-b0gyocxy
# Copying avro_python3-1.10.2-py3.9.egg to e:\anaconda\envs\tfod2\lib\site-packages
# Adding avro-python3 1.10.2 to easy-install.pth file
# Installing avro script to E:\Anaconda\envs\tfod2\Scripts
#
# Installed e:\anaconda\envs\tfod2\lib\site-packages\avro_python3-1.10.2-py3.9.egg
# Searching for tensorflow-text>=2.7.0
# Reading https://pypi.org/simple/tensorflow-text/
# Downloading https://files.pythonhosted.org/packages/72/1c/006bf7894330ae6c750707127afe9bfb5f0c6408cd8149abd7cf6d4cc40b/tensorflow_text-2.7.3-cp39-cp39-win_amd64.whl#sha256=53fa5c9b83120dad5e54fea49c44548e3d526bd6a618b1d9c2d9acf2a3484394
# Best match: tensorflow-text 2.7.3
# Processing tensorflow_text-2.7.3-cp39-cp39-win_amd64.whl
# Installing tensorflow_text-2.7.3-cp39-cp39-win_amd64.whl to e:\anaconda\envs\tfod2\lib\site-packages
# Adding tensorflow-text 2.7.3 to easy-install.pth file
#
# Installed e:\anaconda\envs\tfod2\lib\site-packages\tensorflow_text-2.7.3-py3.9-win-amd64.egg
# Searching for tensorflow-model-optimization>=0.4.1
# Reading https://pypi.org/simple/tensorflow-model-optimization/
# Downloading https://files.pythonhosted.org/packages/75/98/2405187c549550239ada11d89173231f3137ebde34ae74b673b9296e36b1/tensorflow_model_optimization-0.7.0-py2.py3-none-any.whl#sha256=2bed386351718fd242a8df50cfb3d35a3219db1fb48d27c10824ffe008b6a43d
# Best match: tensorflow-model-optimization 0.7.0
# Processing tensorflow_model_optimization-0.7.0-py2.py3-none-any.whl
# Installing tensorflow_model_optimization-0.7.0-py2.py3-none-any.whl to e:\anaconda\envs\tfod2\lib\site-packages
# Adding tensorflow-model-optimization 0.7.0 to easy-install.pth file
#
# Installed e:\anaconda\envs\tfod2\lib\site-packages\tensorflow_model_optimization-0.7.0-py3.9.egg
# Searching for tensorflow-datasets
# Reading https://pypi.org/simple/tensorflow-datasets/
# Downloading https://files.pythonhosted.org/packages/93/83/85f14bcf27df5ae23502803502f8506eefec18a285fea909aa67dc9b736e/tensorflow_datasets-4.4.0-py3-none-any.whl#sha256=b373e7b724a357637d15f29a11bb7bef3dc62bd144defffe5fec1b8b4f6cf580
# Best match: tensorflow-datasets 4.4.0
# Processing tensorflow_datasets-4.4.0-py3-none-any.whl
# Installing tensorflow_datasets-4.4.0-py3-none-any.whl to e:\anaconda\envs\tfod2\lib\site-packages
# Adding tensorflow-datasets 4.4.0 to easy-install.pth file
# Installing tfds-script.py script to E:\Anaconda\envs\tfod2\Scripts
# Installing tfds.exe script to E:\Anaconda\envs\tfod2\Scripts
#
# Installed e:\anaconda\envs\tfod2\lib\site-packages\tensorflow_datasets-4.4.0-py3.9.egg
# Searching for seqeval
# Reading https://pypi.org/simple/seqeval/
# Downloading https://files.pythonhosted.org/packages/9d/2d/233c79d5b4e5ab1dbf111242299153f3caddddbb691219f363ad55ce783d/seqeval-1.2.2.tar.gz#sha256=f28e97c3ab96d6fcd32b648f6438ff2e09cfba87f05939da9b3970713ec56e6f
# Best match: seqeval 1.2.2
# Processing seqeval-1.2.2.tar.gz
# Writing C:\Users\chira\AppData\Local\Temp\easy_install-o_1h39vs\seqeval-1.2.2\setup.cfg
# Running seqeval-1.2.2\setup.py -q bdist_egg --dist-dir C:\Users\chira\AppData\Local\Temp\easy_install-o_1h39vs\seqeval-1.2.2\egg-dist-tmp-a_4dj6q1
# Copying seqeval-1.2.2-py3.9.egg to e:\anaconda\envs\tfod2\lib\site-packages
# Adding seqeval 1.2.2 to easy-install.pth file
#
# Installed e:\anaconda\envs\tfod2\lib\site-packages\seqeval-1.2.2-py3.9.egg
# Searching for sentencepiece
# Reading https://pypi.org/simple/sentencepiece/
# Downloading https://files.pythonhosted.org/packages/ac/2e/e451116a475ffcb8670394df1592ddb8b8b283328895ff73ba04be29a082/sentencepiece-0.1.96-cp39-cp39-win_amd64.whl#sha256=d45e3f78e746aa161bc9f5a31c6a2839c512101113a4065f4d2e7a3ab8198d8c
# Best match: sentencepiece 0.1.96
# Processing sentencepiece-0.1.96-cp39-cp39-win_amd64.whl
# Installing sentencepiece-0.1.96-cp39-cp39-win_amd64.whl to e:\anaconda\envs\tfod2\lib\site-packages
# Adding sentencepiece 0.1.96 to easy-install.pth file
#
# Installed e:\anaconda\envs\tfod2\lib\site-packages\sentencepiece-0.1.96-py3.9-win-amd64.egg
# Searching for sacrebleu
# Reading https://pypi.org/simple/sacrebleu/
# Downloading https://files.pythonhosted.org/packages/fa/63/b3c11f951eafa2dc296862431f29fb12dbe191cb72217cf88ed04c32086b/sacrebleu-2.0.0-py3-none-any.whl#sha256=1acae0221e27c23c4987834fd17b284b4addc6556941c2097c4d618baa2d67af
# Best match: sacrebleu 2.0.0
# Processing sacrebleu-2.0.0-py3-none-any.whl
# Installing sacrebleu-2.0.0-py3-none-any.whl to e:\anaconda\envs\tfod2\lib\site-packages
# Adding sacrebleu 2.0.0 to easy-install.pth file
# Installing sacrebleu-script.py script to E:\Anaconda\envs\tfod2\Scripts
# Installing sacrebleu.exe script to E:\Anaconda\envs\tfod2\Scripts
#
# Installed e:\anaconda\envs\tfod2\lib\site-packages\sacrebleu-2.0.0-py3.9.egg
# Searching for py-cpuinfo>=3.3.0
# Reading https://pypi.org/simple/py-cpuinfo/
# Downloading https://files.pythonhosted.org/packages/e6/ba/77120e44cbe9719152415b97d5bfb29f4053ee987d6cb63f55ce7d50fadc/py-cpuinfo-8.0.0.tar.gz#sha256=5f269be0e08e33fd959de96b34cd4aeeeacac014dd8305f70eb28d06de2345c5
# Best match: py-cpuinfo 8.0.0
# Processing py-cpuinfo-8.0.0.tar.gz
# Writing C:\Users\chira\AppData\Local\Temp\easy_install-pm8mpvxb\py-cpuinfo-8.0.0\setup.cfg
# Running py-cpuinfo-8.0.0\setup.py -q bdist_egg --dist-dir C:\Users\chira\AppData\Local\Temp\easy_install-pm8mpvxb\py-cpuinfo-8.0.0\egg-dist-tmp-wh29gaqt
# creating e:\anaconda\envs\tfod2\lib\site-packages\py_cpuinfo-8.0.0-py3.9.egg
# Extracting py_cpuinfo-8.0.0-py3.9.egg to e:\anaconda\envs\tfod2\lib\site-packages
# byte-compiling e:\anaconda\envs\tfod2\lib\site-packages\py_cpuinfo-8.0.0-py3.9.egg\cpuinfo\__init__.py to __init__.cpython-39.pyc
# byte-compiling e:\anaconda\envs\tfod2\lib\site-packages\py_cpuinfo-8.0.0-py3.9.egg\cpuinfo\__main__.py to __main__.cpython-39.pyc
# byte-compiling e:\anaconda\envs\tfod2\lib\site-packages\py_cpuinfo-8.0.0-py3.9.egg\cpuinfo\cpuinfo.py to cpuinfo.cpython-39.pyc
# Adding py-cpuinfo 8.0.0 to easy-install.pth file
# Installing cpuinfo-script.py script to E:\Anaconda\envs\tfod2\Scripts
# Installing cpuinfo.exe script to E:\Anaconda\envs\tfod2\Scripts
#
# Installed e:\anaconda\envs\tfod2\lib\site-packages\py_cpuinfo-8.0.0-py3.9.egg
# Searching for psutil>=5.4.3
# Reading https://pypi.org/simple/psutil/
# Downloading https://files.pythonhosted.org/packages/9e/9e/3a48f15a1539505e2f3058a709eee56acfb379f2b0ff409d6291099e2a7e/psutil-5.9.0-cp39-cp39-win_amd64.whl#sha256=7d190ee2eaef7831163f254dc58f6d2e2a22e27382b936aab51c835fc080c3d3
# Best match: psutil 5.9.0
# Processing psutil-5.9.0-cp39-cp39-win_amd64.whl
# Installing psutil-5.9.0-cp39-cp39-win_amd64.whl to e:\anaconda\envs\tfod2\lib\site-packages
# Adding psutil 5.9.0 to easy-install.pth file
#
# Installed e:\anaconda\envs\tfod2\lib\site-packages\psutil-5.9.0-py3.9-win-amd64.egg
# Searching for opencv-python-headless
# Reading https://pypi.org/simple/opencv-python-headless/
# Downloading https://files.pythonhosted.org/packages/a7/87/8c001e3bc96b1337a32f9970872708c5b2ccdc6937452d5b85605226b6e6/opencv_python_headless-4.5.5.62-cp36-abi3-win_amd64.whl#sha256=e8a8c02ee060ae30a31be27fb65527c9698a6aa0fec967b49d6e56ea4473d6be
# Best match: opencv-python-headless 4.5.5.62
# Processing opencv_python_headless-4.5.5.62-cp36-abi3-win_amd64.whl
# Installing opencv_python_headless-4.5.5.62-cp36-abi3-win_amd64.whl to e:\anaconda\envs\tfod2\lib\site-packages
# Adding opencv-python-headless 4.5.5.62 to easy-install.pth file
#
# Installed e:\anaconda\envs\tfod2\lib\site-packages\opencv_python_headless-4.5.5.62-py3.9-win-amd64.egg
# Searching for oauth2client
# Reading https://pypi.org/simple/oauth2client/
# Downloading https://files.pythonhosted.org/packages/95/a9/4f25a14d23f0786b64875b91784607c2277eff25d48f915e39ff0cff505a/oauth2client-4.1.3-py2.py3-none-any.whl#sha256=b8a81cc5d60e2d364f0b1b98f958dbd472887acaf1a5b05e21c28c31a2d6d3ac
# Best match: oauth2client 4.1.3
# Processing oauth2client-4.1.3-py2.py3-none-any.whl
# Installing oauth2client-4.1.3-py2.py3-none-any.whl to e:\anaconda\envs\tfod2\lib\site-packages
# Adding oauth2client 4.1.3 to easy-install.pth file
#
# Installed e:\anaconda\envs\tfod2\lib\site-packages\oauth2client-4.1.3-py3.9.egg
# Searching for kaggle>=1.3.9
# Reading https://pypi.org/simple/kaggle/
# Downloading https://files.pythonhosted.org/packages/3a/e7/3bac01547d2ed3d308ac92a0878fbdb0ed0f3d41fb1906c319ccbba1bfbc/kaggle-1.5.12.tar.gz#sha256=b4d87d107bff743aaa805c2b382c3661c4c175cdb159656d4972be2a9cef42cb
# Best match: kaggle 1.5.12
# Processing kaggle-1.5.12.tar.gz
# Writing C:\Users\chira\AppData\Local\Temp\easy_install-2520ivln\kaggle-1.5.12\setup.cfg
# Running kaggle-1.5.12\setup.py -q bdist_egg --dist-dir C:\Users\chira\AppData\Local\Temp\easy_install-2520ivln\kaggle-1.5.12\egg-dist-tmp-kelok7u0
# Copying kaggle-1.5.12-py3.9.egg to e:\anaconda\envs\tfod2\lib\site-packages
# Adding kaggle 1.5.12 to easy-install.pth file
# Installing kaggle-script.py script to E:\Anaconda\envs\tfod2\Scripts
# Installing kaggle.exe script to E:\Anaconda\envs\tfod2\Scripts
#
# Installed e:\anaconda\envs\tfod2\lib\site-packages\kaggle-1.5.12-py3.9.egg
# Searching for google-api-python-client>=1.6.7
# Reading https://pypi.org/simple/google-api-python-client/
# Downloading https://files.pythonhosted.org/packages/fa/4a/0e67e88b1b884b822d805cba0b1dc3a64e4359b655a6db16f61c6f983783/google_api_python_client-2.36.0-py2.py3-none-any.whl#sha256=9e8863dec46224d4375cf3834e27ffd4bce79858f0f00a6109a51e3e62b4f3c2
# Best match: google-api-python-client 2.36.0
# Processing google_api_python_client-2.36.0-py2.py3-none-any.whl
# Installing google_api_python_client-2.36.0-py2.py3-none-any.whl to e:\anaconda\envs\tfod2\lib\site-packages
# Adding google-api-python-client 2.36.0 to easy-install.pth file
#
# Installed e:\anaconda\envs\tfod2\lib\site-packages\google_api_python_client-2.36.0-py3.9.egg
# Searching for typing-extensions<4,>=3.7.0
# Reading https://pypi.org/simple/typing-extensions/
# Downloading https://files.pythonhosted.org/packages/74/60/18783336cc7fcdd95dae91d73477830aa53f5d3181ae4fe20491d7fc3199/typing_extensions-3.10.0.2-py3-none-any.whl#sha256=f1d25edafde516b146ecd0613dabcc61409817af4766fbbcfb8d1ad4ec441a34
# Best match: typing-extensions 3.10.0.2
# Processing typing_extensions-3.10.0.2-py3-none-any.whl
# Installing typing_extensions-3.10.0.2-py3-none-any.whl to e:\anaconda\envs\tfod2\lib\site-packages
# Adding typing-extensions 3.10.0.2 to easy-install.pth file
#
# Installed e:\anaconda\envs\tfod2\lib\site-packages\typing_extensions-3.10.0.2-py3.9.egg
# Searching for pydot<2,>=1.2.0
# Reading https://pypi.org/simple/pydot/
# Downloading https://files.pythonhosted.org/packages/ea/76/75b1bb82e9bad3e3d656556eaa353d8cd17c4254393b08ec9786ac8ed273/pydot-1.4.2-py2.py3-none-any.whl#sha256=66c98190c65b8d2e2382a441b4c0edfdb4f4c025ef9cb9874de478fb0793a451
# Best match: pydot 1.4.2
# Processing pydot-1.4.2-py2.py3-none-any.whl
# Installing pydot-1.4.2-py2.py3-none-any.whl to e:\anaconda\envs\tfod2\lib\site-packages
# Adding pydot 1.4.2 to easy-install.pth file
#
# Installed e:\anaconda\envs\tfod2\lib\site-packages\pydot-1.4.2-py3.9.egg
# Searching for pyarrow<7.0.0,>=0.15.1
# Reading https://pypi.org/simple/pyarrow/
# Downloading https://files.pythonhosted.org/packages/16/a9/3516aa39065f6004951b1a6f6d9f782c8745fd437b6946ffbf6c4b8d66df/pyarrow-6.0.1-cp39-cp39-win_amd64.whl#sha256=2403c8af207262ce8e2bc1a9d19313941fd2e424f1cb3c4b749c17efe1fd699a
# Best match: pyarrow 6.0.1
# Processing pyarrow-6.0.1-cp39-cp39-win_amd64.whl
# Installing pyarrow-6.0.1-cp39-cp39-win_amd64.whl to e:\anaconda\envs\tfod2\lib\site-packages
# Adding pyarrow 6.0.1 to easy-install.pth file
# Installing plasma_store-script.py script to E:\Anaconda\envs\tfod2\Scripts
# Installing plasma_store.exe script to E:\Anaconda\envs\tfod2\Scripts
#
# Installed e:\anaconda\envs\tfod2\lib\site-packages\pyarrow-6.0.1-py3.9-win-amd64.egg
# Searching for proto-plus<2,>=1.7.1
# Reading https://pypi.org/simple/proto-plus/
# Downloading https://files.pythonhosted.org/packages/07/7b/de05a560f979c4b63b8c09163f533e4313b058f652d40677afeb6394e235/proto_plus-1.19.8-py3-none-any.whl#sha256=3434eadaed845a337d6c488d2b7d055d733aaa231c0c0d4c778ec720bb91cf87
# Best match: proto-plus 1.19.8
# Processing proto_plus-1.19.8-py3-none-any.whl
# Installing proto_plus-1.19.8-py3-none-any.whl to e:\anaconda\envs\tfod2\lib\site-packages
# Adding proto-plus 1.19.8 to easy-install.pth file
#
# Installed e:\anaconda\envs\tfod2\lib\site-packages\proto_plus-1.19.8-py3.9.egg
# Searching for pymongo<4.0.0,>=3.8.0
# Reading https://pypi.org/simple/pymongo/
# Downloading https://files.pythonhosted.org/packages/f2/d4/19f06d35317eede30703b88fb4869ac3b78f542df6b9edff14ab5c1178fb/pymongo-3.12.3-cp39-cp39-win_amd64.whl#sha256=dfa217bf8cf3ff6b30c8e6a89014e0c0e7b50941af787b970060ae5ba04a4ce5
# Best match: pymongo 3.12.3
# Processing pymongo-3.12.3-cp39-cp39-win_amd64.whl
# Installing pymongo-3.12.3-cp39-cp39-win_amd64.whl to e:\anaconda\envs\tfod2\lib\site-packages
# Adding pymongo 3.12.3 to easy-install.pth file
#
# Installed e:\anaconda\envs\tfod2\lib\site-packages\pymongo-3.12.3-py3.9-win-amd64.egg
# Obtaining file:///D:/Research/FutDetectV2/Tensorflow/models/research/slim
# Requirement already satisfied: six in e:\anaconda\envs\tfod2\lib\site-packages (from slim==0.1) (1.16.0)
# Requirement already satisfied: tf-slim>=1.1 in e:\anaconda\envs\tfod2\lib\site-packages (from slim==0.1) (1.1.0)
# Requirement already satisfied: absl-py>=0.2.2 in e:\anaconda\envs\tfod2\lib\site-packages (from tf-slim>=1.1->slim==0.1) (1.0.0)
# Installing collected packages: slim
#   Attempting uninstall: slim
#     Found existing installation: slim 0.1
#     Uninstalling slim-0.1:
#       Successfully uninstalled slim-0.1
#   Running setup.py develop for slim
# Successfully installed slim-0.1

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}
# Out:
# 2022-01-25 10:36:52.203065: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-01-25 10:36:52.203117: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-01-25 10:36:57.241517: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-01-25 10:36:57.241545: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-01-25 10:36:57.249048: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: LAPTOP-183BOGU1
# 2022-01-25 10:36:57.249160: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: LAPTOP-183BOGU1
# Running tests under Python 3.9.7: E:\Anaconda\envs\tfod2\python.exe
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2022-01-25 10:36:57.258139: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# E:\Anaconda\envs\tfod2\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\builders\model_builder.py:1100: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn(('Building experimental DeepMAC meta-arch.'
# W0125 10:36:57.616158   108 model_builder.py:1100] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.64s
# I0125 10:36:57.885267   108 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.64s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 1.23s
# I0125 10:36:59.110779   108 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 1.23s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.29s
# I0125 10:36:59.401455   108 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.29s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.39s
# I0125 10:36:59.786864   108 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.39s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 2.12s
# I0125 10:37:01.909931   108 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 2.12s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I0125 10:37:01.910931   108 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.03s
# I0125 10:37:01.935946   108 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.03s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# I0125 10:37:01.951947   108 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# I0125 10:37:01.970950   108 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.11s
# I0125 10:37:02.081146   108 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.11s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.1s
# I0125 10:37:02.184155   108 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.1s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.1s
# I0125 10:37:02.288160   108 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.1s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.11s
# I0125 10:37:02.403181   108 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.11s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.1s
# I0125 10:37:02.505189   108 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.1s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.03s
# I0125 10:37:02.534192   108 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.03s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I0125 10:37:02.887217   108 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b0
# I0125 10:37:02.887217   108 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 64
# I0125 10:37:02.887217   108 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 3
# I0125 10:37:02.890211   108 efficientnet_model.py:147] round_filter input=32 output=32
# I0125 10:37:02.907212   108 efficientnet_model.py:147] round_filter input=32 output=32
# I0125 10:37:02.908212   108 efficientnet_model.py:147] round_filter input=16 output=16
# I0125 10:37:02.976226   108 efficientnet_model.py:147] round_filter input=16 output=16
# I0125 10:37:02.977225   108 efficientnet_model.py:147] round_filter input=24 output=24
# I0125 10:37:03.136225   108 efficientnet_model.py:147] round_filter input=24 output=24
# I0125 10:37:03.136225   108 efficientnet_model.py:147] round_filter input=40 output=40
# I0125 10:37:03.292983   108 efficientnet_model.py:147] round_filter input=40 output=40
# I0125 10:37:03.292983   108 efficientnet_model.py:147] round_filter input=80 output=80
# I0125 10:37:03.571710   108 efficientnet_model.py:147] round_filter input=80 output=80
# I0125 10:37:03.571710   108 efficientnet_model.py:147] round_filter input=112 output=112
# I0125 10:37:03.837732   108 efficientnet_model.py:147] round_filter input=112 output=112
# I0125 10:37:03.837732   108 efficientnet_model.py:147] round_filter input=192 output=192
# I0125 10:37:04.209748   108 efficientnet_model.py:147] round_filter input=192 output=192
# I0125 10:37:04.209748   108 efficientnet_model.py:147] round_filter input=320 output=320
# I0125 10:37:04.301943   108 efficientnet_model.py:147] round_filter input=1280 output=1280
# I0125 10:37:04.352946   108 efficientnet_model.py:457] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0125 10:37:04.417696   108 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b1
# I0125 10:37:04.418685   108 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 88
# I0125 10:37:04.418685   108 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 4
# I0125 10:37:04.420694   108 efficientnet_model.py:147] round_filter input=32 output=32
# I0125 10:37:04.436699   108 efficientnet_model.py:147] round_filter input=32 output=32
# I0125 10:37:04.436699   108 efficientnet_model.py:147] round_filter input=16 output=16
# I0125 10:37:04.565924   108 efficientnet_model.py:147] round_filter input=16 output=16
# I0125 10:37:04.565924   108 efficientnet_model.py:147] round_filter input=24 output=24
# I0125 10:37:04.829145   108 efficientnet_model.py:147] round_filter input=24 output=24
# I0125 10:37:04.829145   108 efficientnet_model.py:147] round_filter input=40 output=40
# I0125 10:37:05.097166   108 efficientnet_model.py:147] round_filter input=40 output=40
# I0125 10:37:05.097166   108 efficientnet_model.py:147] round_filter input=80 output=80
# I0125 10:37:05.438881   108 efficientnet_model.py:147] round_filter input=80 output=80
# I0125 10:37:05.438881   108 efficientnet_model.py:147] round_filter input=112 output=112
# I0125
efficientnet_model.py:147] round_filter input=16 output=32
# I0125 10:37:24.569171   108 efficientnet_model.py:147] round_filter input=16 output=32
# I0125 10:37:24.569171   108 efficientnet_model.py:147] round_filter input=24 output=48
# I0125 10:37:25.594122   108 efficientnet_model.py:147] round_filter input=24 output=48
# I0125 10:37:25.594122   108 efficientnet_model.py:147] round_filter input=40 output=80
# I0125 10:37:26.392122   108 efficientnet_model.py:147] round_filter input=40 output=80
# I0125 10:37:26.392122   108 efficientnet_model.py:147] round_filter input=80 output=160
# I0125 10:37:27.384824   108 efficientnet_model.py:147] round_filter input=80 output=160
# I0125 10:37:27.384824   108 efficientnet_model.py:147] round_filter input=112 output=224
# I0125 10:37:28.500462   108 efficientnet_model.py:147] round_filter input=112 output=224
# I0125 10:37:28.500462   108 efficientnet_model.py:147] round_filter input=192 output=384
# I0125 10:37:30.257351   108 efficientnet_model.py:147] round_filter input=192 output=384
# I0125 10:37:30.257351   108 efficientnet_model.py:147] round_filter input=320 output=640
# I0125 10:37:30.957841   108 efficientnet_model.py:147] round_filter input=1280 output=2560
# I0125 10:37:31.043267   108 efficientnet_model.py:457] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 28.65s
# I0125 10:37:31.184632   108 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 28.65s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0125 10:37:31.184632   108 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.02s
# I0125 10:37:31.200244   108 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.02s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0125 10:37:31.200244   108 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0125 10:37:31.200244   108 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0125 10:37:31.200244   108 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0125 10:37:31.200244   108 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0125 10:37:31.200244   108 test_util.py:2308] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 33.955s
#
# OK (skipped=1)

# %%
# !pip install tensorflow --upgrade

# %%
# !pip uninstall protobuf matplotlib -y
# !pip install protobuf matplotlib==3.2

# %%
import object_detection

# %%
# !pip list

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
# 100% [........................................................................] 20515344 / 20515344        1 file(s) moved.
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/saved_model.pb
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %% [markdown]
# # 2. Create Label Map

# %%
labels = [{'name':'Football', 'id':1}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. Create TF records

# %%
# OPTIONAL IF RUNNING ON COLAB
ARCHIVE_FILES = os.path.join(paths['IMAGE_PATH'], 'archive.tar.gz')
if os.path.exists(ARCHIVE_FILES):
  # !tar -zxvf {ARCHIVE_FILES}

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}
# Out:
# Cloning into 'Tensorflow\scripts'...

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\train.record
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\test.record

# %% [markdown]
# # 4. Copy Model Config to Training Folder

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
# Out:
#         1 file(s) copied.

# %% [markdown]
# # 5. Update Config For Transfer Learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 320
#        width: 320
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 50000
#          warmup_learning_rate: 0.026666000485420227
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # 6. Train the model

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=2000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --num_train_steps=2000

# %%
# !{command}

# %% [markdown]
# # 7. Evaluate the Model

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet

# %%
# !{command}

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-3')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 9. Detect from an Image

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'thumbsup.157163ba-7c1c-11ec-a54a-04d4c46e7bec.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # 10. Real Time Detections from your Webcam

# %%
# !pip uninstall opencv-python-headless -y

# %%
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while cap.isOpened(): 
    ret, frame = cap.read()
    image_np = np.array(frame)
    
    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
    detections = detect_fn(input_tensor)
    
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
                image_np_with_detections,
                detections['detection_boxes'],
                detections['detection_classes']+label_id_offset,
                detections['detection_scores'],
                category_index,
                use_normalized_coordinates=True,
                max_boxes_to_draw=5,
                min_score_thresh=.8,
                agnostic_mode=False)

    cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break

# %% [markdown]
# # 10. Freezing the Graph

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\exporter_main_v2.py  --input_type=image_tensor --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --trained_checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet --output_directory=Tensorflow\workspace\models\my_ssd_mobnet\export

# %%
# !{command}
# Out:
# 2022-01-24 11:56:02.004256: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-01-24 11:56:02.004336: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-01-24 11:56:12.602446: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-01-24 11:56:12.602491: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-01-24 11:56:12.611901: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: LAPTOP-183BOGU1
# 2022-01-24 11:56:12.612131: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: LAPTOP-183BOGU1
# 2022-01-24 11:56:12.628658: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From E:\Anaconda\envs\tfod2\lib\site-packages\tensorflow\python\autograph\impl\api.py:464: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0124 11:56:13.451187  3508 deprecation.py:614] From E:\Anaconda\envs\tfod2\lib\site-packages\tensorflow\python\autograph\impl\api.py:464: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x000001B5FC90ED00>, because it is not built.
# W0124 11:56:56.121269  3508 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x000001B5FC90ED00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x000001B5FC9518B0>, because it is not built.
# W0124 11:56:56.431065  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x000001B5FC9518B0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FE261EE0>, because it is not built.
# W0124 11:56:56.431065  3508 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FE261EE0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE261AF0>, because it is not built.
# W0124 11:56:56.431065  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE261AF0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x000001B5FCD9E160>, because it is not built.
# W0124 11:56:56.431065  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x000001B5FCD9E160>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FE267F10>, because it is not built.
# W0124 11:56:56.431065  3508 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FE267F10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE267FD0>, because it is not built.
# W0124 11:56:56.431065  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE267FD0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x000001B5FCCA82E0>, because it is not built.
# W0124 11:56:56.431065  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x000001B5FCCA82E0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FCE8DA00>, because it is not built.
# W0124 11:56:56.431065  3508 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FCE8DA00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FCCE8790>, because it is not built.
# W0124 11:56:56.431065  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FCCE8790>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x000001B5FE1D5340>, because it is not built.
# W0124 11:56:56.431065  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x000001B5FE1D5340>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FCC7A490>, because it is not built.
# W0124 11:56:56.431065  3508 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FCC7A490>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE447BB0>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE447BB0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FCB581C0>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FCB581C0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FCBF2A30>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FCBF2A30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FE474EB0>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FE474EB0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE474550>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE474550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FE474280>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FE474280>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE474910>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE474910>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FE4746D0>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FE4746D0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FCA24F70>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FCA24F70>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FCB581F0>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FCB581F0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FCA61A60>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FCA61A60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FE45C4C0>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FE45C4C0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE45CEE0>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE45CEE0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FCD2CDF0>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FCD2CDF0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FCD2C6D0>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FCD2C6D0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FCF06970>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FCF06970>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FCF06310>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FCF06310>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FCB58220>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FCB58220>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE570310>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE570310>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FE4E9D00>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FE4E9D00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE4E9940>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE4E9940>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FE268E80>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FE268E80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE2688E0>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE2688E0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FE268F40>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FE268F40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE268FA0>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE268FA0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FE1B4BE0>, because it is not built.
# W0124 11:56:56.435095  3508 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FE1B4BE0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE475C40>, because it is not built.
# W0124 11:56:56.439126  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE475C40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FDF03A60>, because it is not built.
# W0124 11:56:56.439126  3508 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FDF03A60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FCBE4460>, because it is not built.
# W0124 11:56:56.439126  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FCBE4460>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FDF76C70>, because it is not built.
# W0124 11:56:56.439126  3508 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FDF76C70>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE5C2400>, because it is not built.
# W0124 11:56:56.439126  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FE5C2400>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FCC96160>, because it is not built.
# W0124 11:56:56.439126  3508 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001B5FCC96160>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FCC96A00>, because it is not built.
# W0124 11:56:56.439126  3508 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001B5FCC96A00>, because it is not built.
# 2022-01-24 11:57:17.931515: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# W0124 11:57:52.589141  3508 save.py:263] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxPredictor_layer_call_fn while saving (showing 5 of 260). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Tensorflow\workspace\models\my_ssd_mobnet\export\saved_model\assets
# I0124 11:58:05.119003  3508 builder_impl.py:783] Assets written to: Tensorflow\workspace\models\my_ssd_mobnet\export\saved_model\assets
# INFO:tensorflow:Writing pipeline config file to Tensorflow\workspace\models\my_ssd_mobnet\export\pipeline.config
# I0124 11:58:07.418751  3508 config_util.py:253] Writing pipeline config file to Tensorflow\workspace\models\my_ssd_mobnet\export\pipeline.config

# %% [markdown]
# # 11. Conversion to TFJS

# %%
# !pip install tensorflowjs
# Out:
# Collecting tensorflowjs
#   Downloading tensorflowjs-3.13.0-py3-none-any.whl (77 kB)
# Collecting tensorflow-hub<0.13,>=0.7.0
#   Downloading tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
# Requirement already satisfied: tensorflow<3,>=2.1.0 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorflowjs) (2.7.0)
# Requirement already satisfied: six<2,>=1.12.0 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorflowjs) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.13.3)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.4.0)
# Requirement already satisfied: libclang>=9.0.1 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (12.0.0)
# Requirement already satisfied: h5py>=2.9.0 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (4.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.43.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.7.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.23.1)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.7.0)
# Requirement already satisfied: astunparse>=1.6.0 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.2)
# Requirement already satisfied: google-pasta>=0.1.1 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: absl-py>=0.4.0 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.0.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.0)
# Requirement already satisfied: numpy>=1.14.5 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.22.1)
# Requirement already satisfied: tensorboard~=2.6 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.8.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.37.1)
# Requirement already satisfied: protobuf>=3.9.2 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.19.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.3.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (2.27.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (2.3.3)
# Requirement already satisfied: setuptools>=41.0.0 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (60.5.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (2.0.2)
# Requirement already satisfied: markdown>=2.6.8 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (3.3.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in e:\anaconda\envs\tfod2\lib\site-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (1.8.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in e:\anaconda\envs\tfod2\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in e:\anaconda\envs\tfod2\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in e:\anaconda\envs\tfod2\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in e:\anaconda\envs\tfod2\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in e:\anaconda\envs\tfod2\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in e:\anaconda\envs\tfod2\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in e:\anaconda\envs\tfod2\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in e:\anaconda\envs\tfod2\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in e:\anaconda\envs\tfod2\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (2.0.10)
# Requirement already satisfied: idna<4,>=2.5 in e:\anaconda\envs\tfod2\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in e:\anaconda\envs\tfod2\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (1.26.8)
# Requirement already satisfied: oauthlib>=3.0.0 in e:\anaconda\envs\tfod2\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (3.1.1)
# Installing collected packages: tensorflow-hub, tensorflowjs
# Successfully installed tensorflow-hub-0.12.0 tensorflowjs-3.13.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-models-official 2.7.0 requires google-api-python-client>=1.6.7, which is not installed.
# tf-models-official 2.7.0 requires kaggle>=1.3.9, which is not installed.
# tf-models-official 2.7.0 requires oauth2client, which is not installed.
# tf-models-official 2.7.0 requires opencv-python-headless, which is not installed.
# tf-models-official 2.7.0 requires psutil>=5.4.3, which is not installed.
# tf-models-official 2.7.0 requires py-cpuinfo>=3.3.0, which is not installed.
# tf-models-official 2.7.0 requires sacrebleu, which is not installed.
# tf-models-official 2.7.0 requires sentencepiece, which is not installed.
# tf-models-official 2.7.0 requires seqeval, which is not installed.
# tf-models-official 2.7.0 requires tensorflow-datasets, which is not installed.
# tf-models-official 2.7.0 requires tensorflow-model-optimization>=0.4.1, which is not installed.
# tf-models-official 2.7.0 requires tensorflow-text>=2.7.0, which is not installed.

# %%
command = "tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default {} {}".format(os.path.join(paths['OUTPUT_PATH'], 'saved_model'), paths['TFJS_PATH'])

# %%
print(command)
# Out:
# tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default Tensorflow\workspace\models\my_ssd_mobnet\export\saved_model Tensorflow\workspace\models\my_ssd_mobnet\tfjsexport

# %%
# !{command}
# Out:
# Writing weight file Tensorflow\workspace\models\my_ssd_mobnet\tfjsexport\model.json...
# 2022-01-24 12:01:17.309028: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-01-24 12:01:17.309108: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-01-24 12:01:26.781972: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-01-24 12:01:26.782018: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-01-24 12:01:26.792663: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: LAPTOP-183BOGU1
# 2022-01-24 12:01:26.792840: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: LAPTOP-183BOGU1
# 2022-01-24 12:01:26.793297: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-01-24 12:01:52.960845: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2022-01-24 12:01:52.961204: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2022-01-24 12:01:53.675284: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1149] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: Graph size after: 3843 nodes (3433), 5137 edges (4720), time = 375.115ms.
#   function_optimizer: function_optimizer did nothing. time = 7.569ms.
#
# 2022-01-24 12:02:03.383898: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1149] Optimization results for grappler item: graph_to_optimize
#   model_pruner: Graph size after: 3115 nodes (-441), 4467 edges (-441), time = 151.767ms.
#   constant_folding: Graph size after: 1534 nodes (-1581), 2637 edges (-1830), time = 322.205ms.
#   arithmetic_optimizer: Graph size after: 1550 nodes (16), 2647 edges (10), time = 77.603ms.
#   dependency_optimizer: Graph size after: 1463 nodes (-87), 1660 edges (-987), time = 55.418ms.
#   model_pruner: Graph size after: 1463 nodes (0), 1660 edges (0), time = 26.815ms.
#   constant_folding: Graph size after: 1463 nodes (0), 1660 edges (0), time = 101.423ms.
#   arithmetic_optimizer: Graph size after: 1463 nodes (0), 1660 edges (0), time = 73.7ms.
#   dependency_optimizer: Graph size after: 1463 nodes (0), 1660 edges (0), time = 48.92ms.
#   debug_stripper: Graph size after: 1463 nodes (0), 1660 edges (0), time = 14.455ms.
#   model_pruner: Graph size after: 1461 nodes (-2), 1658 edges (-2), time = 45.864ms.
#   constant_folding: Graph size after: 1461 nodes (0), 1658 edges (0), time = 90.81ms.
#   arithmetic_optimizer: Graph size after: 1461 nodes (0), 1658 edges (0), time = 71.129ms.
#   dependency_optimizer: Graph size after: 1456 nodes (-5), 1648 edges (-10), time = 40.089ms.
#   model_pruner: Graph size after: 1456 nodes (0), 1648 edges (0), time = 28.134ms.
#   constant_folding: Graph size after: 1456 nodes (0), 1648 edges (0), time = 92.877ms.
#   arithmetic_optimizer: Graph size after: 1456 nodes (0), 1648 edges (0), time = 70.865ms.
#   dependency_optimizer: Graph size after: 1456 nodes (0), 1648 edges (0), time = 40.788ms.
#   debug_stripper: debug_stripper did nothing. time = 5.172ms.
#
# 2022-01-24 12:02:28.547434: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1149] Optimization results for grappler item: graph_to_optimize
#   remapper: Graph size after: 1420 nodes (-112), 1308 edges (-112), time = 19.977ms.
#   constant_folding: Graph size after: 1116 nodes (-304), 1308 edges (0), time = 106.429ms.
#   arithmetic_optimizer: Graph size after: 1116 nodes (0), 1308 edges (0), time = 57.225ms.
#   dependency_optimizer: Graph size after: 1116 nodes (0), 1308 edges (0), time = 42.058ms.
#   remapper: Graph size after: 1116 nodes (0), 1308 edges (0), time = 17.925ms.
#   constant_folding: Graph size after: 1116 nodes (0), 1308 edges (0), time = 68.145ms.
#   arithmetic_optimizer: Graph size after: 1116 nodes (0), 1308 edges (0), time =